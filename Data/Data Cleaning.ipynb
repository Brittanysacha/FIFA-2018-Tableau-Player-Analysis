# %%
import pandas as pd

# %%
#Import FIFA XSLX 
fifa_df = pd.read_excel('/Users/brittanyharding/LHL-Projects/Tableau-Project/fifa18.xlsx', engine='openpyxl')

# %%
#Run duplicate check
duplicates = fifa_df.duplicated()
# 52 duplicates were returned below
fifa_df[duplicates]
# Out:
#        Wage (€)  Value (€)             Name  Age    Nationality  Overall
# 1373      19000   13000000          Pozuelo   25          Spain       78  \
# 1532      24000   10000000         K. Mbodj   27        Senegal       78
# 5700      95000   10500000           Danilo   25         Brazil       78
# 5739      95000   13000000       J. Lingard   24        England       78
# 6173      17000    8500000        B. Reynet   26         France       78
# 6319      24000   14000000       V. Rongier   22         France       78
# 6433      28000   14500000      V. Koziello   21         France       78
# 6483      43000   14000000       L. Tousart   20         France       78
# 7771      25000   12000000        M. Weiser   23        Germany       78
# 7773      25000   12500000         N. Stark   22        Germany       78
# 7791      31000   16500000       C. Pulisic   18  United States       78
# 7942      30000   11500000        D. Heintz   23        Germany       78
# ...

# %%
# Drop Duplicates from main table
fifa_df = fifa_df.drop_duplicates()

# %%
# Run Check on Data Types and Null Values
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17929 entries, 0 to 17980
# Data columns (total 75 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Wage (€)                           17929 non-null  int64
#  1   Value (€)                          17929 non-null  int64
#  2   Name                               17929 non-null  object
#  3   Age                                17929 non-null  int64
#  4   Nationality                        17929 non-null  object
#  5   Overall                            17929 non-null  int64
#  6   Potential                          17929 non-null  int64
#  7   League                             17681 non-null  object
#  8   Country of Play                    17681 non-null  object
#  9   Club                               17929 non-null  object
#  10  Division Level                     17929 non-null  int64
# ...

# %%
# Export to new clean 
fifa_df.to_excel('Clean_Fifa_Data.xlsx', index=False)

# %% [markdown]
# ###### The Null values belong to player positional catergories. Since not all players have capabilities in every positional options, the null catergories will be left as null values as to not skew the dataset with unnessecary low values, or to remove important data from other areas.
